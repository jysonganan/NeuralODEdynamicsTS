# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

# %%
class dynSys(object):
    
    def __init__(self, param, plot_param_x, plot_param_y, plot_param_traj_x, plot_param_traj_y, plot_param_traj_t):
        self.param = param
        self.plot_param_x = plot_param_x
        self.plot_param_y = plot_param_y
        self.plot_param_traj_x = plot_param_traj_x
        self.plot_param_traj_y = plot_param_traj_y
        self.plot_param_traj_t = plot_param_traj_t
    
    def sys_equation(self, h, t):
        x, y = h
        denom1 = 1 + np.exp(-self.param[4]*x-self.param[5]*y-self.param[10])
        denom2 = 1 + np.exp(-self.param[6]*x-self.param[7]*y-self.param[11])
        s1 = (-1/2)*(x - np.tanh(self.param[0]*x/denom1 + self.param[1]*y/denom2 + self.param[8]))
        s2 = (-1/2)*(y - np.tanh(self.param[2]*x/denom1 + self.param[3]*y/denom2 + self.param[9]))
        return [s1, s2]
    
    
    def arrow_plot(self):
        x = np.linspace(self.plot_param_x[0], self.plot_param_x[1], self.plot_param_x[2])
        y = np.linspace(self.plot_param_y[0], self.plot_param_y[1], self.plot_param_y[2])
        
        X, Y = np.meshgrid(x, y)
        t = 0
        u, v = np.zeros(X.shape), np.zeros(Y.shape)
        NI, NJ = X.shape
        
        for i in range(NI):
            for j in range(NJ):
                x = X[i, j]
                y = Y[i, j]
                yprime = self.sys_equation([x, y], t)
                u[i,j] = yprime[0]
                v[i,j] = yprime[1]
                
        Q = plt.quiver(X, Y, u, v, color='r')

        
        plt.xlabel('$x$')
        plt.ylabel('$y$')
        plt.xlim([self.plot_param_x[0], self.plot_param_x[1]])
        plt.ylim([self.plot_param_y[0], self.plot_param_y[1]])
        
        
    def trajectory_plot(self):
        for x0 in self.plot_param_traj_x:
            for y0 in self.plot_param_traj_y:
                n0 = [x0, y0]
                ys = odeint(self.sys_equation, n0, self.plot_param_traj_t)
                plt.plot(ys[:,0], ys[:,1], 'b-') # path
       
        plt.xlim([self.plot_param_x[0], self.plot_param_x[1]])
        plt.ylim([self.plot_param_y[0], self.plot_param_y[1]])

# %%
param = [3, 0, 0, 3, 0, 0, 0, 0, 0, 0, 0, 0]
plot_param_x = [-1.5, 1.5, 30]
plot_param_y = [-1.5, 1.5, 30]
plot_param_traj_t = np.linspace(0, 500, 1000)
plot_param_traj_x = np.linspace(-1.5, 1.5, 10)
plot_param_traj_y = np.linspace(-1.5, 1.5, 10)

trial1 = dynSys(param = param, plot_param_x = plot_param_x, plot_param_y = plot_param_y, 
                plot_param_traj_x = plot_param_traj_x, plot_param_traj_y = plot_param_traj_y, 
                plot_param_traj_t = plot_param_traj_t)
trial1.arrow_plot()
trial1.trajectory_plot()
plt.show()

# %%
param = [2, 0, 0, 2, 5, 8, 8, 5, 0, 0, 5, 5]
plot_param_x = [-1.5, 1.5, 30]
plot_param_y = [-1.5, 1.5, 30]
plot_param_traj_t = np.linspace(0, 500, 1000)
plot_param_traj_x = np.linspace(-1.5, 1.5, 10)
plot_param_traj_y = np.linspace(-1.5, 1.5, 10)

trial2 = dynSys(param = param, plot_param_x = plot_param_x, plot_param_y = plot_param_y, 
                plot_param_traj_x = plot_param_traj_x, plot_param_traj_y = plot_param_traj_y, 
                plot_param_traj_t = plot_param_traj_t)
trial2.arrow_plot()
trial2.trajectory_plot()
plt.show()

# %%
param = [2, 0, 0, 2, -1, 0, 0, -1, 0, 0, 0, 0]
plot_param_x = [-1.5, 1.5, 30]
plot_param_y = [-1.5, 1.5, 30]
plot_param_traj_t = np.linspace(0, 500, 1000)
plot_param_traj_x = np.linspace(-1.5, 1.5, 10)
plot_param_traj_y = np.linspace(-1.5, 1.5, 10)

trial3 = dynSys(param = param, plot_param_x = plot_param_x, plot_param_y = plot_param_y, 
                plot_param_traj_x = plot_param_traj_x, plot_param_traj_y = plot_param_traj_y, 
                plot_param_traj_t = plot_param_traj_t)
trial3.arrow_plot()
trial3.trajectory_plot()
plt.show()

# %%
param = [2, 0, 0, 2, 1, -2, 3, 1, -0.06, 0, 0.2, -0.85]
plot_param_x = [-1.5, 1.5, 30]
plot_param_y = [-1.5, 1.5, 30]
plot_param_traj_t = np.linspace(0, 500, 1000)
plot_param_traj_x = np.linspace(-1.5, 1.5, 10)
plot_param_traj_y = np.linspace(-1.5, 1.5, 10)

trial4 = dynSys(param = param, plot_param_x = plot_param_x, plot_param_y = plot_param_y, 
                plot_param_traj_x = plot_param_traj_x, plot_param_traj_y = plot_param_traj_y, 
                plot_param_traj_t = plot_param_traj_t)
trial4.arrow_plot()
trial4.trajectory_plot()
plt.show()

# %%
param = [2, 0, 0, 2, 5, 9, 5, 9, 0, 0, 0, 0]
plot_param_x = [-1.5, 1.5, 30]
plot_param_y = [-1.5, 1.5, 30]
plot_param_traj_t = np.linspace(0, 500, 1000)
plot_param_traj_x = np.linspace(-1.5, 1.5, 10)
plot_param_traj_y = np.linspace(-1.5, 1.5, 10)

trial5 = dynSys(param = param, plot_param_x = plot_param_x, plot_param_y = plot_param_y, 
                plot_param_traj_x = plot_param_traj_x, plot_param_traj_y = plot_param_traj_y, 
                plot_param_traj_t = plot_param_traj_t)
trial5.arrow_plot()
trial5.trajectory_plot()
plt.show()

# %%
param = [2, 0, 0, 2, 5, 9, 9, 5, 0, 0, 0, 0]
plot_param_x = [-1.5, 1.5, 30]
plot_param_y = [-1.5, 1.5, 30]
plot_param_traj_t = np.linspace(0, 500, 1000)
plot_param_traj_x = np.linspace(-1.5, 1.5, 10)
plot_param_traj_y = np.linspace(-1.5, 1.5, 10)

trial6 = dynSys(param = param, plot_param_x = plot_param_x, plot_param_y = plot_param_y, 
                plot_param_traj_x = plot_param_traj_x, plot_param_traj_y = plot_param_traj_y, 
                plot_param_traj_t = plot_param_traj_t)
trial6.arrow_plot()
trial6.trajectory_plot()
plt.show()

# %%
param = [1.5, -2.598, 2.598, 1.5, 0, 0, 0, 0, 0, 0, 0, 0]
plot_param_x = [-1.5, 1.5, 30]
plot_param_y = [-1.5, 1.5, 30]
plot_param_traj_t = np.linspace(0, 500, 1000)
plot_param_traj_x = np.linspace(-1.5, 1.5, 10)
plot_param_traj_y = np.linspace(-1.5, 1.5, 10)

trial7 = dynSys(param = param, plot_param_x = plot_param_x, plot_param_y = plot_param_y, 
                plot_param_traj_x = plot_param_traj_x, plot_param_traj_y = plot_param_traj_y, 
                plot_param_traj_t = plot_param_traj_t)
trial7.arrow_plot()
trial7.trajectory_plot()
plt.show()

# %%
param = [2.4271, -1.7634, 1.7634, 2.4271, 0, 0, 0, 0, 0, 0, 0, 0]
plot_param_x = [-1.5, 1.5, 30]
plot_param_y = [-1.5, 1.5, 30]
plot_param_traj_t = np.linspace(0, 500, 1000)
plot_param_traj_x = np.linspace(-1.5, 1.5, 10)
plot_param_traj_y = np.linspace(-1.5, 1.5, 10)

trial8 = dynSys(param = param, plot_param_x = plot_param_x, plot_param_y = plot_param_y, 
                plot_param_traj_x = plot_param_traj_x, plot_param_traj_y = plot_param_traj_y, 
                plot_param_traj_t = plot_param_traj_t)
trial8.arrow_plot()
trial8.trajectory_plot()
plt.show()

# %%
param = [2.9665, -0.4471, 0.4471, 2.9665, 0, 0, 0, 0, 0, 0, 0, 0]
plot_param_x = [-1.5, 1.5, 30]
plot_param_y = [-1.5, 1.5, 30]
plot_param_traj_t = np.linspace(0, 500, 1000)
plot_param_traj_x = np.linspace(-1.5, 1.5, 10)
plot_param_traj_y = np.linspace(-1.5, 1.5, 10)

trial8 = dynSys(param = param, plot_param_x = plot_param_x, plot_param_y = plot_param_y, 
                plot_param_traj_x = plot_param_traj_x, plot_param_traj_y = plot_param_traj_y, 
                plot_param_traj_t = plot_param_traj_t)
trial8.arrow_plot()
trial8.trajectory_plot()
plt.show()

# %%
## limit cycle
np.random.seed(23)

def f(h, t):
    x, y = h
    s1 = x - x**3/3 - y + np.asscalar(np.random.normal(0.7, 0.2, 1)[0])
    s2 = (1/12.5)*(x + 0.7 - 0.8 * y)
    return [s1, s2]


x = np.linspace(-2, 2, 30)
y = np.linspace(-2, 3, 30)


X, Y = np.meshgrid(x, y)


t = 0
u, v = np.zeros(X.shape), np.zeros(Y.shape)
NI, NJ = X.shape


# plot the arrows
for i in range(NI):
    for j in range(NJ):
        x = X[i, j]
        y = Y[i, j]
        yprime = f([x, y], t)
        u[i,j] = yprime[0]
        v[i,j] = yprime[1]
     

Q = plt.quiver(X, Y, u, v, color='r')

plt.xlabel('$x$')
plt.ylabel('$y$')
plt.xlim([-2, 2])
plt.ylim([-2, 3])

plot_param_traj_t = np.linspace(0, 10, 100)
plot_param_traj_x = np.linspace(-2, 2, 12)
plot_param_traj_y = np.linspace(-2, 3, 12)


for x0 in plot_param_traj_x:
    for y0 in plot_param_traj_y:
        x0 = float(x0)
        y0 = float(y0)
        n0 = [x0, y0]
        ys = odeint(f, n0, plot_param_traj_t)
        plt.plot(ys[:,0], ys[:,1], 'b-') # path
        plt.xlim([-2, 2])
        plt.ylim([-2, 3])

plt.show()
# Out:
# /Applications/anaconda/envs/py36/lib/python3.6/site-packages/scipy/integrate/odepack.py:218: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# /Applications/anaconda/envs/py36/lib/python3.6/site-packages/scipy/integrate/odepack.py:218: ODEintWarning: Repeated convergence failures (perhaps bad Jacobian or tolerances). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
